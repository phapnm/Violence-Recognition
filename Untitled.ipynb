# %%
import json

# %%
with open('result.json') as f:
    data = json.load(f)

# %%
data
# Out:
# []

# %%
import pandas as pd

data = pd.read_pickle(r'./rwf_v1.pkl')

# %%
import pprint
pprint.pprint(data)
# Out:
# [array([0.99311715, 0.00688291], dtype=float32),
#  array([0.68992734, 0.31007272], dtype=float32),
#  array([0.9823896, 0.0176104], dtype=float32),
#  array([0.9916904 , 0.00830969], dtype=float32),
#  array([0.9908442 , 0.00915586], dtype=float32),
#  array([0.98291224, 0.01708779], dtype=float32),
#  array([0.9170922 , 0.08290789], dtype=float32),
#  array([0.9096908 , 0.09030928], dtype=float32),
#  array([0.72165966, 0.27834043], dtype=float32),
#  array([0.98936975, 0.01063026], dtype=float32),
#  array([0.9961073 , 0.00389279], dtype=float32),
#  array([9.9976116e-01, 2.3884441e-04], dtype=float32),
#  array([0.9622134 , 0.03778668], dtype=float32),
#  array([0.9871857 , 0.01281432], dtype=float32),
#  array([0.75186723, 0.24813284], dtype=float32),
#  array([0.97733194, 0.02266811], dtype=float32),
#  array([0.902078  , 0.09792206], dtype=float32),
#  array([0.38701808, 0.612982  ], dtype=float32),
#  array([0.93154234, 0.06845772], dtype=float32),
# ...

# %%
len(data)
# Out:
# 398

# %%
data3 = pd.read_pickle(r'./rwf_v1.pkl')

# %%
pprint.pprint(data3)
print(len(data3))
# Out:
# [array([0.99311715, 0.00688291], dtype=float32),
#  array([0.68992734, 0.31007272], dtype=float32),
#  array([0.9823896, 0.0176104], dtype=float32),
#  array([0.9916904 , 0.00830969], dtype=float32),
#  array([0.9908442 , 0.00915586], dtype=float32),
#  array([0.98291224, 0.01708779], dtype=float32),
#  array([0.9170922 , 0.08290789], dtype=float32),
#  array([0.9096908 , 0.09030928], dtype=float32),
#  array([0.72165966, 0.27834043], dtype=float32),
#  array([0.98936975, 0.01063026], dtype=float32),
#  array([0.9961073 , 0.00389279], dtype=float32),
#  array([9.9976116e-01, 2.3884441e-04], dtype=float32),
#  array([0.9622134 , 0.03778668], dtype=float32),
#  array([0.9871857 , 0.01281432], dtype=float32),
#  array([0.75186723, 0.24813284], dtype=float32),
#  array([0.97733194, 0.02266811], dtype=float32),
#  array([0.902078  , 0.09792206], dtype=float32),
#  array([0.38701808, 0.612982  ], dtype=float32),
#  array([0.93154234, 0.06845772], dtype=float32),
# ...

# %%
print(len(data2))
# Out:
# 400

# %%
data4 = pd.read_pickle(r'./rwf_v3.pkl')

# %%
pprint.pprint(data4)
print(len(data4))
# Out:
# [array([0.9497355 , 0.05026454], dtype=float32),
#  array([0.98816484, 0.01183521], dtype=float32),
#  array([0.32105327, 0.6789468 ], dtype=float32),
#  array([0.9183778, 0.0816223], dtype=float32),
#  array([0.99766046, 0.00233963], dtype=float32),
#  array([0.65846926, 0.3415309 ], dtype=float32),
#  array([0.8798896, 0.1201105], dtype=float32),
#  array([0.64113104, 0.35886896], dtype=float32),
#  array([0.9811871 , 0.01881299], dtype=float32),
#  array([0.99880046, 0.00119954], dtype=float32),
#  array([0.99575543, 0.00424459], dtype=float32),
#  array([0.9968476 , 0.00315236], dtype=float32),
#  array([0.9978811, 0.0021189], dtype=float32),
#  array([0.24581307, 0.7541869 ], dtype=float32),
#  array([0.79679555, 0.2032045 ], dtype=float32),
#  array([0.9971612 , 0.00283886], dtype=float32),
#  array([0.9974129 , 0.00258708], dtype=float32),
#  array([9.9970609e-01, 2.9397794e-04], dtype=float32),
#  array([0.70105666, 0.29894343], dtype=float32),
# ...

# %%
data4[16]
# Out:
# array([0.9974129 , 0.00258708], dtype=float32)

# %%
data5 = pd.read_pickle(r'./rwf_v4.pkl')

# %%
pprint.pprint(data5)
print(len(data5))
# Out:
# [array([0.9497355 , 0.05026454], dtype=float32),
#  array([0.98816484, 0.01183521], dtype=float32),
#  array([0.32105327, 0.6789468 ], dtype=float32),
#  array([0.9183778, 0.0816223], dtype=float32),
#  array([0.99766046, 0.00233963], dtype=float32),
#  array([0.65846926, 0.3415309 ], dtype=float32),
#  array([0.8798896, 0.1201105], dtype=float32),
#  array([0.64113104, 0.35886896], dtype=float32),
#  array([0.9811871 , 0.01881299], dtype=float32),
#  array([0.99880046, 0.00119954], dtype=float32),
#  array([0.99575543, 0.00424459], dtype=float32),
#  array([0.9968476 , 0.00315236], dtype=float32),
#  array([0.9978811, 0.0021189], dtype=float32),
#  array([0.24581307, 0.7541869 ], dtype=float32),
#  array([0.79679555, 0.2032045 ], dtype=float32),
#  array([0.9971612 , 0.00283886], dtype=float32),
#  array([0.9974129 , 0.00258708], dtype=float32),
#  array([9.9970609e-01, 2.9397794e-04], dtype=float32),
#  array([0.70105666, 0.29894343], dtype=float32),
# ...

# %%
data4[16]
# Out:
# array([0.9974129 , 0.00258708], dtype=float32)
